# %% [markdown]
# # Детекция лиц с OpenCV
# ## Интерактивная демонстрация работы детектора лиц

# %%
# Установка необходимых библиотек

# %%
# Импорт необходимых библиотек

import pip
import cv2
import numpy as np
import matplotlib.pyplot as plt
import os

# Проверка версии OpenCV
print(f"OpenCV версия: {cv2.__version__}")
# Out:
# OpenCV версия: 4.10.0

# %%
# Инициализация детектора лиц
cascade_path = cv2.data.haarcascades + 'haarcascade_frontalface_default.xml'

if not os.path.exists(cascade_path):
    raise FileNotFoundError(f"Файл каскада не найден: {cascade_path}")

face_cascade = cv2.CascadeClassifier(cascade_path)

if face_cascade.empty():
    raise ValueError("Не удалось загрузить каскад Хаара")

print("Детектор лиц инициализирован успешно")
# Out:
# Детектор лиц инициализирован успешно

# %%
# Загрузка изображения
image_path = "D:/Apps/GitHub/KSP-Hub/My-CV-Engineering-Projects/CV-010_face_detection/assets/input.jpg"

if not os.path.exists(image_path):
    raise FileNotFoundError(f"Файл изображения не найден: {image_path}")

img = cv2.imread(image_path)
if img is None:
    raise ValueError("Не удалось загрузить изображение")

gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
print(f"Изображение загружено. Размер: {img.shape}")
# Out:
# Изображение загружено. Размер: (464, 1293, 3)

# %%
# Детекция лиц
faces = face_cascade.detectMultiScale(
    gray,
    scaleFactor=1.10500,
    minNeighbors=5,
    minSize=(30, 30),
    flags=cv2.CASCADE_SCALE_IMAGE
)

print(f"Найдено {len(faces)} лиц")
faces
# Out:
# Найдено 8 лиц
# array([[1094,   96,   57,   57],
#        [ 778,   87,   58,   58],
#        [ 157,  287,   58,   58],
#        [ 138,  107,   57,   57],
#        [ 460,  294,   54,   54],
#        [1080,  278,   58,   58],
#        [ 461,  102,   62,   62],
#        [ 740,  286,   64,   64]], dtype=int32)

# %%
# Визуализация результатов
img_result = img.copy()

for (x, y, w, h) in faces:
    cv2.rectangle(img_result, (x, y), (x+w, y+h), (255, 0, 0), 2)
    cv2.putText(img_result, f'Face', (x, y-10), 
                cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 0, 0), 1)

# Отображение результата
plt.figure(figsize=(12, 8))
plt.imshow(cv2.cvtColor(img_result, cv2.COLOR_BGR2RGB))
plt.title(f"Результат детекции лиц (найдено: {len(faces)})")
plt.axis('off')
plt.show()

# %%
# Сохранение результата
output_path = "D:/Apps/GitHub/KSP-Hub/My-CV-Engineering-Projects/results/output_notebook.jpg"
cv2.imwrite(output_path, img_result)
print(f"Результат сохранен в: {output_path}")
# Out:
# Результат сохранен в: D:/Apps/GitHub/KSP-Hub/My-CV-Engineering-Projects/results/output_notebook.jpg
